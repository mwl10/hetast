# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../..'))
import torch
import numpy as np
import utils
import matplotlib.pyplot as plt
# %load_ext autoreload
import glob
np.random.seed(2) 
torch.manual_seed(2)

# %%
# %autoreload

# %% [markdown]
# ## load a checkpoint & dataset the network trained on

# %%
lcs = utils.get_data('../../datasets/ZTF_g',min_length=25)
# Out:
# found 3408 for band='g'
# max time:  1687.1367
# created union_tp attribute of length 3500
# dataset created, lcs.dataset.shape=(2831, 1, 1962, 3)
# train size: 2547, valid size: 510, test size: 284

# %%
files = glob.glob('../checkpoints/g/*')
files
# Out:
# ['../checkpoints/g/ZTF_g0.9460071325302124.h5',
#  '../checkpoints/g/ZTF_g1.1252859830856323.h5',
#  '../checkpoints/g/ZTF_g1.1747798919677734.h5',
#  '../checkpoints/g/ZTF_g1.154257893562317.h5',
#  '../checkpoints/g/ZTF_g0.9446610808372498.h5',
#  '../checkpoints/g/ZTF_g1.1041532754898071.h5']

# %%
for file in files:
    net,optimizer,scheduler,lrs, args, epoch, losses = utils.load_checkpoint(file, lcs.data_obj)
    print('------------------------------------')
    print(f'{args.factor=}')
    print(losses[0][-1])
    print('------------------------------------')
    train_l = np.array(losses[0])
    
    val_l = np.array(losses[1])
    test_l = np.array(losses[2])
    fs = 15
    fig, ax = plt.subplots(5, figsize=(10,10))
    ax[0].set_title('Learning Curves for g model',fontsize=fs)
    ax[2].set_xlabel('Epoch',fontsize=fs)
    print(ax)
    ## NLL
    x = np.arange(0,len(losses[0])*10,10) # took metrics every 10 itrs
    ax[0].plot(x,train_l[:,0], label='train')
    ax[0].plot(x,test_l[:,0], label='test')
    ax[0].plot(x,val_l[:,0], label='val')
    ax[0].set_ylim(0.6,1.5)
    ax[0].legend(loc="upper right")
    ax[0].set_ylabel('Average NLL',fontsize=fs)
    ## MSE
    ax[1].plot(x, train_l[:,1], label='train')
    ax[1].plot(x, test_l[:,1], label='test')
    ax[1].plot(x,val_l[:,1], label='val')
    ax[1].set_ylabel('Average MSE',fontsize=fs)
    ## KL Annealing
    ax[2].plot(x,train_l[:,2])
    ax[2].set_ylabel('KL loss',fontsize=fs)

    ax[3].plot(lrs)
    ax[3].set_ylabel('LR',fontsize=fs)
    try:
        ax[4].plot(train_l[:,3])
    except Exception:
        pass
# Out:
# => loading checkpoint '../checkpoints/g/ZTF_g0.9460071325302124.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint=None, seed=2, device='mps', net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=8, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=10000, batch_size=2, k_iwae=1, lr=0.0001, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.9, lr_patience=35, threshold=0.01, dropout=0.1, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=32, start=0.0, stop=0.8, ratio=0.5, keep_missing=False, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, num_resamples=0, is_bounded=True)
# ------------------------------------
# args.factor=0.9
# [0.9460071325302124, 0.4614579975605011, 0.00012558902380988002, 0.8]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]
# => loading checkpoint '../checkpoints/g/ZTF_g1.1252859830856323.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint=None, seed=2, device='mps', keep_missing=False, net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=16, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=1000, batch_size=2, k_iwae=1, lr=0.0001, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.9, lr_patience=40, threshold=0.01, dropout=0.0, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=32, start=0.0, stop=0.1, ratio=0.5, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, std=0.1, num_resamples=0, is_bounded=True)
# ------------------------------------
# args.factor=0.9
# [1.1252859830856323, 0.3917452096939087, 0.4694952964782715, 0.02453333333333334]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]
# => loading checkpoint '../checkpoints/g/ZTF_g1.1747798919677734.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint=None, seed=2, device='mps', net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=16, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=1000, batch_size=2, k_iwae=1, lr=0.0003, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.5, lr_patience=30, threshold=0.01, dropout=0.0, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, std=0.1, num_resamples=0, is_bounded=True)
# ------------------------------------
# args.factor=0.5
# [1.1747798919677734, 0.46847182512283325, 6.077795842429623e-05]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]
# => loading checkpoint '../checkpoints/g/ZTF_g1.154257893562317.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint=None, seed=2, device='mps', keep_missing=False, net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=16, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=1000, batch_size=2, k_iwae=1, lr=0.0003, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.9, lr_patience=40, threshold=0.01, dropout=0.0, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=32, start=0.0, stop=0.1, ratio=0.5, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, num_resamples=0, is_bounded=True, std=0.5)
# ------------------------------------
# args.factor=0.9
# [1.154257893562317, 0.4434016942977905, 0.17590168118476868, 0.1]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]
# => loading checkpoint '../checkpoints/g/ZTF_g0.9446610808372498.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint=None, seed=2, device='mps', net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=8, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=10000, batch_size=2, k_iwae=1, lr=0.0001, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.9, lr_patience=35, threshold=0.01, dropout=0.1, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=32, start=0.0, stop=0.8, ratio=0.5, keep_missing=False, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, num_resamples=0, is_bounded=True)
# ------------------------------------
# args.factor=0.9
# [0.9446610808372498, 0.45929867029190063, 0.00015961214376147836, 0.5802666666666664]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]
# => loading checkpoint '../checkpoints/g/ZTF_g1.1041532754898071.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_g', start_col=1, checkpoint='/home2/fggr82/astr/hetast/src/datasets/ZTF_g1.1316057443618774.h5', seed=2, device='mps', keep_missing=False, net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=16, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=1000, batch_size=2, k_iwae=1, lr=0.0001, beta1=0.9, beta2=0.999, scheduler=False, warmup=10, factor=0.9, lr_patience=40, threshold=0.01, dropout=0.0, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=32, start=0.0, stop=0.1, ratio=0.5, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, num_resamples=0, is_bounded=True, std=0.1)
# ------------------------------------
# args.factor=0.9
# [1.1041532754898071, 0.3507196605205536, 1.0693800449371338, 0.02453333333333334]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]

# %%
factor 0.9 
    increase number of KL cycles
    increase patience slgihtly 
    try less weight on MSE

# %% [markdown]
# # Plot Learning curves
