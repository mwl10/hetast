# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../..'))
import torch
import numpy as np
import utils
import matplotlib.pyplot as plt
# %load_ext autoreload
import glob
np.random.seed(2) 
torch.manual_seed(2)

# %% [markdown]
# ## load a checkpoint & dataset the network trained on

# %%
lcs = utils.get_data('../../datasets/ZTF_r', min_length=25)
# Out:
# found 3398 for band='r'
# max time:  1505.0703
# created union_tp attribute of length 3500
# dataset created, lcs.dataset.shape=(2956, 1, 1988, 3)
# train size: 2660, valid size: 532, test size: 296

# %%
# Out:
# /Users/mattlowery/Desktop/Desko/code/astro/hetast/src/notebooks/learning_curves

# %%
files = glob.glob('../checkpoints/exp_23/*')
files
# Out:
# ['../checkpoints/exp_23/ZTF_r1.1770527362823486.h5',
#  '../checkpoints/exp_23/ZTF_i1.2547202110290527.h5',
#  '../checkpoints/exp_23/ZTF_g1.1559041738510132.h5',
#  '../checkpoints/exp_23/ZTF_g1.1583737134933472.h5']

# %%
train_l[:,3].shape
# Out:
# (51,)

# %%
for file in [files[0]]:
    net,optimizer,scheduler,lrs, args, epoch, losses = utils.load_checkpoint(file, lcs.data_obj)
    print('------------------------------------')
    print(f'{args.factor=}')
    print(losses[0][-1])
    print('------------------------------------')
    train_l = np.array(losses[0])
    
    val_l = np.array(losses[1])
    test_l = np.array(losses[2])
    fs = 15
    fig, ax = plt.subplots(5, figsize=(10,10))
    ax[0].set_title('Learning Curves for g model',fontsize=fs)
    ax[2].set_xlabel('Epoch',fontsize=fs)
    print(ax)
    ## NLL
    x = np.arange(0,len(losses[0])*10,10) # took metrics every 10 itrs
    ax[0].plot(x,train_l[:,0], label='train')
    ax[0].plot(x,test_l[:,0], label='test')
    ax[0].plot(x,val_l[:,0], label='val')
    ax[0].set_ylim(0.6,1.5)
    ax[0].legend(loc="upper right")
    ax[0].set_ylabel('Average NLL',fontsize=fs)
    ## MSE
    ax[1].plot(x, train_l[:,1], label='train')
    ax[1].plot(x, test_l[:,1], label='test')
    ax[1].plot(x,val_l[:,1], label='val')
    ax[1].set_ylabel('Average MSE',fontsize=fs)
    ## KL Annealing
    ax[2].plot(x,train_l[:,2])
    ax[2].set_ylabel('KL loss',fontsize=fs)

    ax[3].plot(lrs)
    ax[3].set_ylabel('LR',fontsize=fs)
    
    ax[4].plot(train_l[:,3])
# Out:
# => loading checkpoint '../checkpoints/exp_23/ZTF_r1.1770527362823486.h5'
# Namespace(data_folder='/home2/fggr82/astr/hetast/src/datasets/ZTF_r', start_col=1, checkpoint=None, seed=2, device='mps', net='HeTVAE', mixing='concat', n_union_tp=3500, embed_time=128, num_heads=16, latent_dim=64, num_ref_points=16, rec_hidden=128, width=512, niters=6000, patience=1000, batch_size=2, k_iwae=1, lr=0.0003, beta1=0.9, beta2=0.999, scheduler=True, warmup=10, factor=0.9, lr_patience=40, threshold=0.01, dropout=0.0, inc_errors=False, frac=0.5, mse_weight=5.0, kl_annealing=True, kl_itrs=6000, n_cycles=64, start=0.0, stop=1.0, ratio=0.5, min_length=25, print_at=1, save_at=30, kl_zero=False, const_var=False, var_per_dim=False, std=0.1, num_resamples=0)
# ------------------------------------
# args.factor=0.9
# [1.1770527362823486, 0.4879978895187378, 9.628954285290092e-05, 0.725333333333333]
# ------------------------------------
# [<AxesSubplot:title={'center':'Learning Curves for g model'}>
#  <AxesSubplot:> <AxesSubplot:xlabel='Epoch'> <AxesSubplot:> <AxesSubplot:>]

# %%
factor 0.9 
    increase number of KL cycles
    increase patience slgihtly 
    try less weight on MSE

# %% [markdown]
# # Plot Learning curves
